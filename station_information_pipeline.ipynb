# %%
import utils.functions as fnc
base_api_url='https://oslo-bike-api-13322556367.europe-west1.run.app'

# %%
station_info = fnc.LocalStorage()

station_info_df = station_info.get_data(base_api_url+'/station_information', ['data','stations'])

# %%
station_info_df
# Out:
#    station_id                     name               address        lat  \
# 0         141     Danielsentoppen Park            Haugekra 1  59.928276
# 1         411     Sivertsenhøgda Plass  Gundersenstykket 38A  59.901694
# 2         301     Simonsenflata Brygge        Lienskogen 00C  59.913498
# 3         373   Gulbrandsenrøa Sentrum   Martinsenplassen 9B  59.925738
# 4         762       Johnsenjordet Park         Haugengata 53  59.911485
# 5         806       Pedersenroa Brygge      Eriksenstubben 1  59.914017
# 6         538      Myhreberget Sentrum   Jacobsenplassen 90A  59.932587
# 7         905   Pettersenvollen Brygge         Strandhøgda 3  59.939070
# 8         474       Sandviktoppen Park    Halvorsenbakken 85  59.904616
# 9         769     Jacobsenhagen Torget       Haugenbråten 82  59.933229
# 10        934        Dahlvollen Torget    Jenssenskrenten 59  59.913792
# 11        713  Kristiansenberget Plass          Brekkeroa 52  59.926635
# 12        957       Mathisenmyra Plass      Engensvingen 11E  59.900732
# 13        431         Viktoppen Torget       Mathisenmarka 6  59.924560
# 14        199   Rønningstranda Stasjon          Lundalléen 7  59.934375
#
#           lon  capacity
# 0   10.700339        29
# 1   10.729487        11
# 2   10.754842        33
# 3   10.794217        18
# 4   10.750922        15
# 5   10.743305        14
# 6   10.787359        34
# 7   10.786907        32
# 8   10.724760        14
# 9   10.765062        35
# 10  10.718603        23
# 11  10.739751        30
# 12  10.783329        34
# 13  10.799091        13
# 14  10.722195        28

# %%
bronze_df = station_info.load_to_bronze(station_info_df, 'station_information')

# %%
bronze_df
# Out:
#    station_id                     name               address        lat  \
# 0         141     Danielsentoppen Park            Haugekra 1  59.928276
# 1         411     Sivertsenhøgda Plass  Gundersenstykket 38A  59.901694
# 2         301     Simonsenflata Brygge        Lienskogen 00C  59.913498
# 3         373   Gulbrandsenrøa Sentrum   Martinsenplassen 9B  59.925738
# 4         762       Johnsenjordet Park         Haugengata 53  59.911485
# 5         806       Pedersenroa Brygge      Eriksenstubben 1  59.914017
# 6         538      Myhreberget Sentrum   Jacobsenplassen 90A  59.932587
# 7         905   Pettersenvollen Brygge         Strandhøgda 3  59.939070
# 8         474       Sandviktoppen Park    Halvorsenbakken 85  59.904616
# 9         769     Jacobsenhagen Torget       Haugenbråten 82  59.933229
# 10        934        Dahlvollen Torget    Jenssenskrenten 59  59.913792
# 11        713  Kristiansenberget Plass          Brekkeroa 52  59.926635
# 12        957       Mathisenmyra Plass      Engensvingen 11E  59.900732
# 13        431         Viktoppen Torget       Mathisenmarka 6  59.924560
# 14        199   Rønningstranda Stasjon          Lundalléen 7  59.934375
#
#           lon  capacity       _ingestion_timestamp _ingestion_date
# 0   10.700339        29 2026-01-18 21:21:15.507817      2026-01-18
# 1   10.729487        11 2026-01-18 21:21:15.507817      2026-01-18
# 2   10.754842        33 2026-01-18 21:21:15.507817      2026-01-18
# 3   10.794217        18 2026-01-18 21:21:15.507817      2026-01-18
# 4   10.750922        15 2026-01-18 21:21:15.507817      2026-01-18
# 5   10.743305        14 2026-01-18 21:21:15.507817      2026-01-18
# 6   10.787359        34 2026-01-18 21:21:15.507817      2026-01-18
# 7   10.786907        32 2026-01-18 21:21:15.507817      2026-01-18
# 8   10.724760        14 2026-01-18 21:21:15.507817      2026-01-18
# 9   10.765062        35 2026-01-18 21:21:15.507817      2026-01-18
# 10  10.718603        23 2026-01-18 21:21:15.507817      2026-01-18
# 11  10.739751        30 2026-01-18 21:21:15.507817      2026-01-18
# 12  10.783329        34 2026-01-18 21:21:15.507817      2026-01-18
# 13  10.799091        13 2026-01-18 21:21:15.507817      2026-01-18
# 14  10.722195        28 2026-01-18 21:21:15.507817      2026-01-18

# %%
silver_df = station_info.transform_to_silver(bronze_df, 'station_information',
                                     transformations = station_info.transform_stations,
                                     quality_checks = station_info.quality_checks_1)

# %%
silver_df
# Out:
#    station_id                     name               address        lat  \
# 0         141     Danielsentoppen Park            Haugekra 1  59.928276
# 1         411     Sivertsenhøgda Plass  Gundersenstykket 38A  59.901694
# 2         301     Simonsenflata Brygge        Lienskogen 00C  59.913498
# 3         373   Gulbrandsenrøa Sentrum   Martinsenplassen 9B  59.925738
# 4         762       Johnsenjordet Park         Haugengata 53  59.911485
# 5         806       Pedersenroa Brygge      Eriksenstubben 1  59.914017
# 6         538      Myhreberget Sentrum   Jacobsenplassen 90A  59.932587
# 7         905   Pettersenvollen Brygge         Strandhøgda 3  59.939070
# 8         474       Sandviktoppen Park    Halvorsenbakken 85  59.904616
# 9         769     Jacobsenhagen Torget       Haugenbråten 82  59.933229
# 10        934        Dahlvollen Torget    Jenssenskrenten 59  59.913792
# 11        713  Kristiansenberget Plass          Brekkeroa 52  59.926635
# 12        957       Mathisenmyra Plass      Engensvingen 11E  59.900732
# 13        431         Viktoppen Torget       Mathisenmarka 6  59.924560
# 14        199   Rønningstranda Stasjon          Lundalléen 7  59.934375
#
#           lon  capacity           address_str             location  \
# 0   10.700339        29            Haugekra 1  59.928276,10.700339
# 1   10.729487        11  Gundersenstykket 38A  59.901694,10.729487
# 2   10.754842        33        Lienskogen 00C  59.913498,10.754842
# 3   10.794217        18   Martinsenplassen 9B  59.925738,10.794217
# 4   10.750922        15         Haugengata 53  59.911485,10.750922
# 5   10.743305        14      Eriksenstubben 1  59.914017,10.743305
# 6   10.787359        34   Jacobsenplassen 90A  59.932587,10.787359
# 7   10.786907        32         Strandhøgda 3   59.93907,10.786907
# 8   10.724760        14    Halvorsenbakken 85   59.904616,10.72476
# 9   10.765062        35       Haugenbråten 82  59.933229,10.765062
# 10  10.718603        23    Jenssenskrenten 59  59.913792,10.718603
# 11  10.739751        30          Brekkeroa 52  59.926635,10.739751
# 12  10.783329        34      Engensvingen 11E  59.900732,10.783329
# 13  10.799091        13       Mathisenmarka 6   59.92456,10.799091
# 14  10.722195        28          Lundalléen 7  59.934375,10.722195
#
#          _processed_timestamp
# 0  2026-01-18 21:21:15.677448
# 1  2026-01-18 21:21:15.677448
# 2  2026-01-18 21:21:15.677448
# 3  2026-01-18 21:21:15.677448
# 4  2026-01-18 21:21:15.677448
# 5  2026-01-18 21:21:15.677448
# 6  2026-01-18 21:21:15.677448
# 7  2026-01-18 21:21:15.677448
# 8  2026-01-18 21:21:15.677448
# 9  2026-01-18 21:21:15.677448
# 10 2026-01-18 21:21:15.677448
# 11 2026-01-18 21:21:15.677448
# 12 2026-01-18 21:21:15.677448
# 13 2026-01-18 21:21:15.677448
# 14 2026-01-18 21:21:15.677448

# %%
def aggregation_1(df):
        df['weird_coord'] = df['lat'] - df['lon']      
        return df

# %%
gold_df = station_info.aggregate_to_gold(silver_df, 'station_infomation', aggregations=aggregation_1)

# %%
gold_df['station_infomation']
# Out:
#    station_id                     name               address        lat  \
# 0         141     Danielsentoppen Park            Haugekra 1  59.928276
# 1         411     Sivertsenhøgda Plass  Gundersenstykket 38A  59.901694
# 2         301     Simonsenflata Brygge        Lienskogen 00C  59.913498
# 3         373   Gulbrandsenrøa Sentrum   Martinsenplassen 9B  59.925738
# 4         762       Johnsenjordet Park         Haugengata 53  59.911485
# 5         806       Pedersenroa Brygge      Eriksenstubben 1  59.914017
# 6         538      Myhreberget Sentrum   Jacobsenplassen 90A  59.932587
# 7         905   Pettersenvollen Brygge         Strandhøgda 3  59.939070
# 8         474       Sandviktoppen Park    Halvorsenbakken 85  59.904616
# 9         769     Jacobsenhagen Torget       Haugenbråten 82  59.933229
# 10        934        Dahlvollen Torget    Jenssenskrenten 59  59.913792
# 11        713  Kristiansenberget Plass          Brekkeroa 52  59.926635
# 12        957       Mathisenmyra Plass      Engensvingen 11E  59.900732
# 13        431         Viktoppen Torget       Mathisenmarka 6  59.924560
# 14        199   Rønningstranda Stasjon          Lundalléen 7  59.934375
#
#           lon  capacity           address_str             location  \
# 0   10.700339        29            Haugekra 1  59.928276,10.700339
# 1   10.729487        11  Gundersenstykket 38A  59.901694,10.729487
# 2   10.754842        33        Lienskogen 00C  59.913498,10.754842
# 3   10.794217        18   Martinsenplassen 9B  59.925738,10.794217
# 4   10.750922        15         Haugengata 53  59.911485,10.750922
# 5   10.743305        14      Eriksenstubben 1  59.914017,10.743305
# 6   10.787359        34   Jacobsenplassen 90A  59.932587,10.787359
# 7   10.786907        32         Strandhøgda 3   59.93907,10.786907
# 8   10.724760        14    Halvorsenbakken 85   59.904616,10.72476
# 9   10.765062        35       Haugenbråten 82  59.933229,10.765062
# 10  10.718603        23    Jenssenskrenten 59  59.913792,10.718603
# 11  10.739751        30          Brekkeroa 52  59.926635,10.739751
# 12  10.783329        34      Engensvingen 11E  59.900732,10.783329
# 13  10.799091        13       Mathisenmarka 6   59.92456,10.799091
# 14  10.722195        28          Lundalléen 7  59.934375,10.722195
#
#     weird_coord
# 0     49.227937
# 1     49.172207
# 2     49.158656
# 3     49.131521
# 4     49.160563
# 5     49.170712
# 6     49.145228
# 7     49.152163
# 8     49.179856
# 9     49.168167
# 10    49.195189
# 11    49.186884
# 12    49.117403
# 13    49.125469
# 14    49.212180

# %%
test = fnc.LocalStorage()
df_map = test.read_latest('gold', 'station_infomation')

# %%
def create_plotly_map(df):
    """
    Create interactive map with Plotly
    - Works great in Jupyter notebooks
    - Hover for information
    - Color-coded by values
    """
    fig = px.scatter_map(
        df,
        lat='lat',
        lon='lon',
        hover_name='name',
        hover_data=['capacity'],
        color='capacity',
        size='capacity',
        color_continuous_scale='Viridis',
        zoom=12,
        height=600,
        title='Bike Stations Map'
    )
    
    fig.update_layout(
        mapbox_style='open-street-map',
        margin={"r": 0, "t": 40, "l": 0, "b": 0}
    )
    
    #fig.show()
    return fig

# %%
import plotly.express as px
create_plotly_map(df_map)
