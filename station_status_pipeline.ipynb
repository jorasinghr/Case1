# %%
import utils.functions as fnc
base_api_url='https://oslo-bike-api-13322556367.europe-west1.run.app'

# %%
station_status = fnc.LocalStorage()

station_status_df = station_status.get_data(base_api_url+'/station_status', ['data','stations'])

# %%
station_status_df
# Out:
#    station_id  is_installed  can_rent  can_return  num_bikes_available  \
# 0         658             1         1           0                   13
# 1         139             1         1           1                   31
# 2         121             1         1           1                   25
# 3         383             1         1           1                    7
# 4         302             1         1           1                    3
# 5         177             1         1           1                   20
# 6         738             1         0           1                    0
# 7         663             1         1           1                    9
# 8         636             1         1           1                   12
# 9         109             1         1           0                   16
# 10        880             1         0           1                    0
# 11        403             1         1           0                   13
# ...

# %%
bronze_df = station_status.load_to_bronze(station_status_df, 'station_status')

# %%
bronze_df
# Out:
#    station_id  is_installed  can_rent  can_return  num_bikes_available  \
# 0         658             1         1           0                   13
# 1         139             1         1           1                   31
# 2         121             1         1           1                   25
# 3         383             1         1           1                    7
# 4         302             1         1           1                    3
# 5         177             1         1           1                   20
# 6         738             1         0           1                    0
# 7         663             1         1           1                    9
# 8         636             1         1           1                   12
# 9         109             1         1           0                   16
# 10        880             1         0           1                    0
# 11        403             1         1           0                   13
# ...

# %%
silver_df = station_status.transform_to_silver(bronze_df, 'station_status',
                                     transformations = station_status.transform_stations,
                                     quality_checks = station_status.quality_checks_1)
# Out:
# [SILVER] Quality check failures: ["Missing columns: ['name']"]

# %%
silver_df
# Out:
#    station_id  is_installed  can_rent  can_return  num_bikes_available  \
# 0         658             1         1           0                   13
# 1         139             1         1           1                   31
# 2         121             1         1           1                   25
# 3         383             1         1           1                    7
# 4         302             1         1           1                    3
# 5         177             1         1           1                   20
# 6         738             1         0           1                    0
# 7         663             1         1           1                    9
# 8         636             1         1           1                   12
# 9         109             1         1           0                   16
# 10        880             1         0           1                    0
# 11        403             1         1           0                   13
# ...

# %%
def aggregation_2(df):
        df = df[df['can_return']==1]      
        return df

# %%
gold_df = station_status.aggregate_to_gold(silver_df, 'station_status', aggregations=aggregation_2)

# %%
gold_df['station_status']
# Out:
#    station_id  is_installed  can_rent  can_return  num_bikes_available  \
# 1         139             1         1           1                   31
# 2         121             1         1           1                   25
# 3         383             1         1           1                    7
# 4         302             1         1           1                    3
# 5         177             1         1           1                   20
# 6         738             1         0           1                    0
# 7         663             1         1           1                    9
# 8         636             1         1           1                   12
# 10        880             1         0           1                    0
# 12        180             1         1           1                   17
# 13        392             1         1           1                   15
#
#     num_docks_available
# 1                     2
# 2                     3
# 3                     3
# ...

# %%
test = fnc.LocalStorage()
test.read_latest('gold', 'station_status')
# Out:
#    station_id  is_installed  can_rent  can_return  num_bikes_available  \
# 0         139             1         1           1                   31
# 1         121             1         1           1                   25
# 2         383             1         1           1                    7
# 3         302             1         1           1                    3
# 4         177             1         1           1                   20
# 5         738             1         0           1                    0
# 6         663             1         1           1                    9
# 7         636             1         1           1                   12
# 8         880             1         0           1                    0
# 9         180             1         1           1                   17
# 10        392             1         1           1                   15
#
#     num_docks_available
# 0                     2
# 1                     3
# 2                     3
# ...
